# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
# %matplotlib inline
from wordcloud import WordCloud

# %%
data=pd.read_excel('hotel_reviews.xlsx')

# %%
data.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...     4.0
# 1  ok nothing special charge diamond member hilto...     2.0
# 2  nice rooms not 4* experience hotel monaco seat...     3.0
# 3  unique, great stay, wonderful time hotel monac...     5.0
# 4  great stay great stay, went seahawk game aweso...     5.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 320.3+ KB

# %%
data.dtypes
# Out:
# Review     object
# Rating    float64
# dtype: object

# %%
len(data) #total number of reviews
# Out:
# 20491

# %%
data['Rating'].value_counts(normalize=True)*100
# Out:
# 5.0    44.185252
# 4.0    29.471475
# 3.0    10.658338
# 2.0     8.750183
# 1.0     6.934752
# Name: Rating, dtype: float64

# %%
ratings=data.groupby(['Rating']).count()
ratings
# Out:
#         Review
# Rating
# 1.0       1421
# 2.0       1793
# 3.0       2184
# 4.0       6039
# 5.0       9054

# %%
plt.figure(figsize=(12,8))
data['Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data.Rating.hist()
data.Rating.hist(bins=10)
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data.describe()
# Out:
#              Rating
# count  20491.000000
# mean       3.952223
# std        1.233030
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
Reviews=data.iloc[:,[1]]

# %%
data.iloc[:,[1]]
# Out:
#        Rating
# 0         4.0
# 1         2.0
# 2         3.0
# 3         5.0
# 4         5.0
# ...       ...
# 20486     5.0
# 20487     4.0
# 20488     2.0
# 20489     1.0
# 20490     2.0
#
# [20491 rows x 1 columns]

# %%
Reviews.shape
# Out:
# (20491, 1)

# %%
Reviews.describe()
# Out:
#              Rating
# count  20491.000000
# mean       3.952223
# std        1.233030
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
Reviews.dtypes
# Out:
# Rating    float64
# dtype: object

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...     4.0
# 1  ok nothing special charge diamond member hilto...     2.0
# 2  nice rooms not 4* experience hotel monaco seat...     3.0
# 3  unique, great stay, wonderful time hotel monac...     5.0
# 4  great stay great stay, went seahawk game aweso...     5.0

# %%
#Converting all review into Lowercase..###
data['Review']= data['Review'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
# removing punctuation from review..#
import string
data['Review']=data['Review'].apply(lambda x:''.join([i for i in x  if i not in string.punctuation]))

# %%
# Remove Numbers from review
data['Review']=data['Review'].str.replace('[0-9]','')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_33676/3690729807.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Review']=data['Review'].str.replace('[0-9]','')

# %%
# removing all stopwords(english)
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')

# %%
data['Review']=data['Review'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
data
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...     4.0
# 1      ok nothing special charge diamond member hilto...     2.0
# 2      nice rooms experience hotel monaco seattle goo...     3.0
# 3      unique great stay wonderful time hotel monaco ...     5.0
# 4      great stay great stay went seahawk game awesom...     5.0
# ...                                                  ...     ...
# 20486  best kept secret rd time staying charm star ca...     5.0
# 20487  great location price view hotel great quick pl...     4.0
# 20488  ok looks nice modern outside desk staff nt par...     2.0
# 20489  hotel theft ruined vacation hotel opened sept ...     1.0
# 20490  people talking ca nt believe excellent ratings...     2.0
#
# [20491 rows x 2 columns]

# %%
from textblob import Word
data['Review']= data['Review'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

import re
pattern = r"((?<=^)|(?<= )).((?=$)|(?= ))"
data['Review']= data['Review'].apply(lambda x:(re.sub(pattern, '',x).strip()))

# %%
data['Review'].head()
# Out:
# 0    nice hotel expensive parking got good deal sta...
# 1    ok nothing special charge diamond member hilto...
# 2    nice room experience hotel monaco seattle good...
# 3    unique great stay wonderful time hotel monaco ...
# 4    great stay great stay went seahawk game awesom...
# Name: Review, dtype: object

# %%
Review_wordcloud = ' '.join(data['Review'])
Q_wordcloud=WordCloud(
                    background_color='black',
                    width=2000,
                    height=2000
                   ).generate(Review_wordcloud)
fig = plt.figure(figsize = (10, 10))
plt.axis('on')
plt.imshow(Q_wordcloud)

# %% [markdown]
# # Removing Punctuation
# The next step is to remove punctuation, as it doesn’t add any extra information while treating text data. Therefore removing all instances of it will help us reduce the size of the training data.

# %%
data['Review'] = data['Review'].str.replace('[^\w\s]','')
data['Review'].head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_33676/1310297486.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Review'] = data['Review'].str.replace('[^\w\s]','')
# 0    nice hotel expensive parking got good deal sta...
# 1    ok nothing special charge diamond member hilto...
# 2    nice room experience hotel monaco seattle good...
# 3    unique great stay wonderful time hotel monaco ...
# 4    great stay great stay went seahawk game awesom...
# Name: Review, dtype: object

# %% [markdown]
# # Common word removal
# Previously, we just removed commonly occurring words in a general sense. We can also remove commonly occurring words from our text data First, let’s check the 10 most frequently occurring words in our text data then take call to remove or retain.

# %%
freq = pd.Series(' '.join(data['Review']).split()).value_counts()[:10]
freq
# Out:
# hotel    52894
# room     46348
# great    21095
# nt       19007
# good     17051
# staff    16277
# stay     15339
# night    14073
# day      12952
# time     12601
# dtype: int64

# %% [markdown]
# # Now, let’s remove these words as their presence will not of any use in classification of our text data.

# %%
data['Review'] = data['Review'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data['Review'].head()
# Out:
# 0    nice expensive parking got deal anniversary ar...
# 1    ok nothing special charge diamond member hilto...
# 2    nice experience monaco seattle levelpositives ...
# 3    unique wonderful monaco location excellent sho...
# 4    went seahawk game awesome downfall view buildi...
# Name: Review, dtype: object

# %% [markdown]
# # Rare words removal
#
# Similarly, just as we removed the most common words, this time let’s remove rarely occurring words from the text. Because they’re so rare, the association between them and other words is dominated by noise. You can replace rare words with a more general form and then this will have higher counts

# %%
freq = pd.Series(' '.join(data['Review']).split()).value_counts()[-10:]
freq
# Out:
# sometimethis     1
# daley            1
# chocalates       1
# profesionally    1
# photogropher     1
# crappie          1
# mesqiuttos       1
# diserve          1
# towelets         1
# swears           1
# dtype: int64
